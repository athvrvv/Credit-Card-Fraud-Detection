# %% [markdown]
# <a href="https://colab.research.google.com/github/athvrvv/Credit-Card-Fraud-Detection/blob/main/Project_Credit_Card_Fraud_Detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Importing the Dependencies

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %%
# loading the dataset to a Pandas DataFrame
credit_card_data = pd.read_csv('/content/creditcard.csv')

# %%
# first 5 rows of the dataset
credit_card_data.head()
# Out:
#    Time        V1        V2        V3        V4  ...       V26       V27       V28  Amount  Class
# 0     0 -1.359807 -0.072781  2.536347  1.378155  ... -0.189115  0.133558 -0.021053  149.62    0.0
# 1     0  1.191857  0.266151  0.166480  0.448154  ...  0.125895 -0.008983  0.014724    2.69    0.0
# 2     1 -1.358354 -1.340163  1.773209  0.379780  ... -0.139097 -0.055353 -0.059752  378.66    0.0
# 3     1 -0.966272 -0.185226  1.792993 -0.863291  ... -0.221929  0.062723  0.061458  123.50    0.0
# 4     2 -1.158233  0.877737  1.548718  0.403034  ...  0.502292  0.219422  0.215153   69.99    0.0
#
# [5 rows x 31 columns]

# %%
credit_card_data.tail()
# Out:
#         Time        V1        V2        V3        V4  ...       V26       V27       V28   Amount  Class
# 51586  45023 -2.943382 -2.332451  2.568959  0.747114  ...  0.356930 -0.006093  0.268288    26.24    0.0
# 51587  45024 -1.278283 -3.726046 -0.902718  2.796542  ... -0.354449 -0.150956  0.269036  1233.16    0.0
# 51588  45024 -0.852261  0.886192 -0.378032 -1.142044  ...  0.255778  0.132317  0.133329    28.98    0.0
# 51589  45024 -0.447740  0.775759  1.586053  0.227702  ...  0.365861  0.353120  0.198239     3.99    0.0
# 51590  45026  1.042380 -1.096464  0.234271 -0.615254  ...       NaN       NaN       NaN      NaN    NaN
#
# [5 rows x 31 columns]

# %%
# dataset information
credit_card_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51591 entries, 0 to 51590
# Data columns (total 31 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Time    51591 non-null  int64
#  1   V1      51591 non-null  float64
#  2   V2      51591 non-null  float64
#  3   V3      51591 non-null  float64
#  4   V4      51591 non-null  float64
#  5   V5      51591 non-null  float64
#  6   V6      51591 non-null  float64
#  7   V7      51591 non-null  float64
#  8   V8      51591 non-null  float64
#  9   V9      51591 non-null  float64
#  10  V10     51591 non-null  float64
#  11  V11     51590 non-null  float64
#  12  V12     51590 non-null  float64
#  13  V13     51590 non-null  float64
#  14  V14     51590 non-null  float64
#  15  V15     51590 non-null  float64
#  16  V16     51590 non-null  float64
#  17  V17     51590 non-null  float64
#  18  V18     51590 non-null  float64
#  19  V19     51590 non-null  float64
#  20  V20     51590 non-null  float64
#  21  V21     51590 non-null  float64
#  22  V22     51590 non-null  float64
#  23  V23     51590 non-null  float64
#  24  V24     51590 non-null  float64
#  25  V25     51590 non-null  float64
#  26  V26     51590 non-null  float64
#  27  V27     51590 non-null  float64
#  28  V28     51590 non-null  float64
#  29  Amount  51590 non-null  float64
#  30  Class   51590 non-null  float64
# dtypes: float64(30), int64(1)
# memory usage: 12.2 MB

# %%
# checking the number of missing values in each column
credit_card_data.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       1
# V12       1
# V13       1
# V14       1
# V15       1
# V16       1
# V17       1
# V18       1
# V19       1
# V20       1
# V21       1
# V22       1
# V23       1
# V24       1
# V25       1
# V26       1
# V27       1
# V28       1
# Amount    1
# Class     1
# dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dataset.shape()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-f363b4e35986> in <cell line: 0>()
# ----> 1 dataset.shape()
#
# NameError: name 'dataset' is not defined

# %%
credit_card_data.shape()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-10-e7ecd970973b> in <cell line: 0>()
# ----> 1 credit_card_data.shape()
#
# TypeError: 'tuple' object is not callable

# %%
credit_card_data.shape
# Out:
# (51591, 31)

# %%
fig, ax= plt.subplots(figsize=(8,8))
sns.distplot(credit_card_data['Amount'])
# Out:
# <ipython-input-12-576abd8c0540>:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(credit_card_data['Amount'])
# <Axes: xlabel='Amount', ylabel='Density'>

# %% [markdown]
# replace missing values with mean

# %%
credit_card_data['Amount'].fillna(credit_card_data['Amount'].mean(),inplace=True)
# Out:
# <ipython-input-13-c76ccc731d63>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   credit_card_data['Amount'].fillna(credit_card_data['Amount'].mean(),inplace=True)

# %%
credit_card_data.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       1
# V12       1
# V13       1
# V14       1
# V15       1
# V16       1
# V17       1
# V18       1
# V19       1
# V20       1
# V21       1
# V22       1
# V23       1
# V24       1
# V25       1
# V26       1
# V27       1
# V28       1
# Amount    0
# Class     1
# dtype: int64

# %%
fig, ax= plt.subplots(figsize=(8,8))
sns.distplot(credit_card_data['V11'])
# Out:
# <ipython-input-15-8041bc269f3c>:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(credit_card_data['V11'])
# <Axes: xlabel='V11', ylabel='Density'>

# %%
credit_card_data['V11'].fillna(credit_card_data['V11'].median(),inplace=True)
# Out:
# <ipython-input-16-49b19e4b4577>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   credit_card_data['V11'].fillna(credit_card_data['V11'].median(),inplace=True)

# %%
credit_card_data.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       1
# V13       1
# V14       1
# V15       1
# V16       1
# V17       1
# V18       1
# V19       1
# V20       1
# V21       1
# V22       1
# V23       1
# V24       1
# V25       1
# V26       1
# V27       1
# V28       1
# Amount    0
# Class     1
# dtype: int64

# %%
fig, ax= plt.subplots(figsize=(8,8))
sns.distplot(credit_card_data['V12'])
# Out:
# <ipython-input-18-8ffb35251708>:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(credit_card_data['V12'])
# <Axes: xlabel='V12', ylabel='Density'>

# %%
credit_card_data['V12'].fillna(credit_card_data['V12'].median(),inplace=True)
# Out:
# <ipython-input-19-b384fbfe8180>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   credit_card_data['V12'].fillna(credit_card_data['V12'].median(),inplace=True)

# %%
credit_card_data.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       1
# V14       1
# V15       1
# V16       1
# V17       1
# V18       1
# V19       1
# V20       1
# V21       1
# V22       1
# V23       1
# V24       1
# V25       1
# V26       1
# V27       1
# V28       1
# Amount    0
# Class     1
# dtype: int64

# %%
fig, ax= plt.subplots(figsize=(8,8))
sns.distplot(credit_card_data['V13']['V14'])

# %%
fig, ax= plt.subplots(figsize=(8,8))
sns.distplot(credit_card_data['V11'])
# Out:
# <ipython-input-21-8041bc269f3c>:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(credit_card_data['V11'])
# <Axes: xlabel='V11', ylabel='Density'>

# %%
fig, ax= plt.subplots(figsize=(8,8))
sns.distplot(credit_card_data['V13']['V14'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-22-f9c162a9d595> in <cell line: 0>()
#       1 fig, ax= plt.subplots(figsize=(8,8))
# ----> 2 sns.distplot(credit_card_data['V13']['V14'])
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/series.py in __getitem__(self, key)
#    1119
#    1120         elif key_is_scalar:
# -> 1121             return self._get_value(key)
#    1122
#    1123         # Convert generator to list before going through hashable part
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/series.py in _get_value(self, label, takeable)
#    1235
#    1236         # Similar to Index.get_value, but we do not fall back to positional
# -> 1237         loc = self.index.get_loc(label)
#    1238
#    1239         if is_integer(loc):
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/indexes/range.py in get_loc(self, key)
#     415                 raise KeyError(key) from err
#     416         if isinstance(key, Hashable):
# --> 417             raise KeyError(key)
#     418         self._check_indexing_error(key)
#     419         raise KeyError(key)
#
# KeyError: 'V14'

# %%
credit_card_data['V14'].fillna(credit_card_data['V14'].median(),inplace=True)
# Out:
# <ipython-input-23-abf1bebaa4c7>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   credit_card_data['V14'].fillna(credit_card_data['V14'].median(),inplace=True)

# %%
credit_card_data.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       1
# V14       0
# V15       1
# V16       1
# V17       1
# V18       1
# V19       1
# V20       1
# V21       1
# V22       1
# V23       1
# V24       1
# V25       1
# V26       1
# V27       1
# V28       1
# Amount    0
# Class     1
# dtype: int64

# %%
credit_card_data['V13'].fillna(credit_card_data['V13'].median(),inplace=True)
credit_card_data['V15'].fillna(credit_card_data['V15'].median(),inplace=True)
# Out:
# <ipython-input-25-5455f0bf8c12>:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   credit_card_data['V15'].fillna(credit_card_data['V15'].median(),inplace=True)

# %%
credit_card_data.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       1
# V17       1
# V18       1
# V19       1
# V20       1
# V21       1
# V22       1
# V23       1
# V24       1
# V25       1
# V26       1
# V27       1
# V28       1
# Amount    0
# Class     1
# dtype: int64

# %%
credit_card_data['V16'].fillna(credit_card_data['V16'].median(),inplace=True)
credit_card_data['V17'].fillna(credit_card_data['V17'].median(),inplace=True)
credit_card_data['V18'].fillna(credit_card_data['V18'].median(),inplace=True)
credit_card_data['V19'].fillna(credit_card_data['V19'].median(),inplace=True)
credit_card_data['V20'].fillna(credit_card_data['V20'].median(),inplace=True)
credit_card_data['V21'].fillna(credit_card_data['V21'].median(),inplace=True)
credit_card_data['V22'].fillna(credit_card_data['V22'].median(),inplace=True)
credit_card_data['V23'].fillna(credit_card_data['V23'].median(),inplace=True)
credit_card_data['V24'].fillna(credit_card_data['V24'].median(),inplace=True)
credit_card_data['V25'].fillna(credit_card_data['V25'].median(),inplace=True)
credit_card_data['V26'].fillna(credit_card_data['V26'].median(),inplace=True)
credit_card_data['V27'].fillna(credit_card_data['V27'].median(),inplace=True)
credit_card_data['V28'].fillna(credit_card_data['V28'].median(),inplace=True)
credit_card_data['Class'].fillna(credit_card_data['Class'].median(),inplace=True)
# Out:
# <ipython-input-27-94f2290a6229>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   credit_card_data['V16'].fillna(credit_card_data['V16'].median(),inplace=True)
# <ipython-input-27-94f2290a6229>:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   credit_card_data['V17'].fillna(credit_card_data['V17'].median(),inplace=True)
# <ipython-input-27-94f2290a6229>:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   credit_card_data['V18'].fillna(credit_card_data['V18'].median(),inplace=True)
# <ipython-input-27-94f2290a6229>:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   credit_card_data['V19'].fillna(credit_card_data['V19'].median(),inplace=True)
# <ipython-input-27-94f2290a6229>:5: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   credit_card_data['V20'].fillna(credit_card_data['V20'].median(),inplace=True)
# <ipython-input-27-94f2290a6229>:6: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   credit_card_data['V21'].fillna(credit_card_data['V21'].median(),inplace=True)
# <ipython-input-27-94f2290a6229>:7: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   credit_card_data['V22'].fillna(credit_card_data['V22'].median(),inplace=True)
# <ipython-input-27-94f2290a6229>:8: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   credit_card_data['V23'].fillna(credit_card_data['V23'].median(),inplace=True)
# <ipython-input-27-94f2290a6229>:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   credit_card_data['V24'].fillna(credit_card_data['V24'].median(),inplace=True)
# <ipython-input-27-94f2290a6229>:10: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   credit_card_data['V25'].fillna(credit_card_data['V25'].median(),inplace=True)
# <ipython-input-27-94f2290a6229>:11: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   credit_card_data['V26'].fillna(credit_card_data['V26'].median(),inplace=True)
# <ipython-input-27-94f2290a6229>:12: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   credit_card_data['V27'].fillna(credit_card_data['V27'].median(),inplace=True)
# <ipython-input-27-94f2290a6229>:13: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   credit_card_data['V28'].fillna(credit_card_data['V28'].median(),inplace=True)
# <ipython-input-27-94f2290a6229>:14: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   credit_card_data['Class'].fillna(credit_card_data['Class'].median(),inplace=True)

# %%
credit_card_data.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %%
# distribution of legit transactions and fradulent transactions
credit_card_data['Class'].value_counts()
# Out:
# Class
# 0.0    51441
# 1.0      150
# Name: count, dtype: int64

# %% [markdown]
# this dataset is highly unbalanced

# %% [markdown]
# 0-->Normal Transaction
#
# 1-->Fradulent Transaction

# %%
 # seperating the data for analysis
 legit = credit_card_data[credit_card_data.Class == 0]
 fraud = credit_card_data[credit_card_data.Class == 1]

# %%
print(legit.shape)
print(fraud.shape)
# Out:
# (51441, 31)
# (150, 31)

# %%
# statistical measures of the data
legit.Amount.describe()
# Out:
# count    51441.000000
# mean        94.000268
# std        253.577916
# min          0.000000
# 25%          7.680000
# 50%         25.390000
# 75%         86.010000
# max      12910.930000
# Name: Amount, dtype: float64

# %%
fraud.Amount.describe()
# Out:
# count     150.000000
# mean       98.848400
# std       232.056904
# min         0.000000
# 25%         1.000000
# 50%         8.370000
# 75%        99.990000
# max      1809.680000
# Name: Amount, dtype: float64

# %%
# compare the values for both transactions
credit_card_data.groupby('Class').mean()
# Out:
#                Time        V1        V2         V3  ...      V26       V27       V28     Amount
# Class                                               ...
# 0.0    29415.586769 -0.222757 -0.011857   0.723973  ...  0.01993  0.002418  0.003911  94.000268
# 1.0    27111.653333 -7.605033  5.403059 -10.281767  ...  0.14826  0.594727  0.030024  98.848400
#
# [2 rows x 30 columns]

# %% [markdown]
# Under-Sampling
#
# Build a sample dataset containing similar distribution of normal Transactions and Fraudulent Transactions

# %% [markdown]
# Number of Fraud Transactions=150

# %%
legit_sample = legit.sample(n=150)

# %% [markdown]
# Concatenating two dataframes

# %%
new_dataset = pd.concat([legit_sample,fraud],axis=0)

# %%
new_dataset.head()
# Out:
#         Time        V1        V2        V3        V4  ...       V26       V27       V28  Amount  Class
# 25897  33814  1.089744  0.190000  1.404807  2.520904  ... -0.042204  0.038711  0.024297    8.95    0.0
# 7103    9309 -2.303127  4.067409 -2.636338  0.797247  ... -0.620064 -0.244766 -1.413820    0.89    0.0
# 30289  35856  1.236976  0.058841  0.324885  0.584026  ...  0.258864  0.007080  0.007696    7.81    0.0
# 3106    2666 -1.467643  3.494228 -3.314919  0.587026  ... -0.314775  1.238524  0.432597    0.89    0.0
# 2630    2157  1.114943 -0.424537  0.030883 -0.081328  ...  1.439247 -0.152243 -0.012181   78.00    0.0
#
# [5 rows x 31 columns]

# %%
new_dataset.tail()
# Out:
#         Time        V1        V2        V3        V4  ...       V26       V27       V28  Amount  Class
# 46998  43028 -1.109646  0.811069 -1.138135  0.935265  ...  0.707654  0.418649  0.080756  204.27    1.0
# 47802  43369 -3.365319  2.426503 -3.752227  0.276017  ... -1.055997 -1.200165 -1.012066   88.00    1.0
# 48094  43494 -1.278138  0.716242 -1.143279  0.217805  ... -0.349793  0.454851  0.137843   24.90    1.0
# 50211  44393 -4.617461  3.663395 -5.297446  3.880960  ... -0.239996 -0.183463 -0.073360    1.00    1.0
# 50537  44532 -0.234922  0.355413  1.972183 -1.255593  ... -0.531846  0.123185  0.039581    1.00    1.0
#
# [5 rows x 31 columns]

# %%
new_dataset['Class'].value_counts()
# Out:
# Class
# 0.0    150
# 1.0    150
# Name: count, dtype: int64

# %%
new_dataset.groupby('Class').mean()
# Out:
#                Time        V1        V2         V3  ...       V26       V27       V28      Amount
# Class                                               ...
# 0.0    28252.906667 -0.126158  0.006417   0.642757  ... -0.037575 -0.077721  0.004514  102.983333
# 1.0    27111.653333 -7.605033  5.403059 -10.281767  ...  0.148260  0.594727  0.030024   98.848400
#
# [2 rows x 30 columns]

# %% [markdown]
# Splitting the data into features and targets

# %%
X = new_dataset.drop(columns='Class',axis=1)
Y = new_dataset['Class']

# %%
print(X)
# Out:
#         Time        V1        V2        V3  ...       V26       V27       V28  Amount
# 25897  33814  1.089744  0.190000  1.404807  ... -0.042204  0.038711  0.024297    8.95
# 7103    9309 -2.303127  4.067409 -2.636338  ... -0.620064 -0.244766 -1.413820    0.89
# 30289  35856  1.236976  0.058841  0.324885  ...  0.258864  0.007080  0.007696    7.81
# 3106    2666 -1.467643  3.494228 -3.314919  ... -0.314775  1.238524  0.432597    0.89
# 2630    2157  1.114943 -0.424537  0.030883  ...  1.439247 -0.152243 -0.012181   78.00
# ...      ...       ...       ...       ...  ...       ...       ...       ...     ...
# 46998  43028 -1.109646  0.811069 -1.138135  ...  0.707654  0.418649  0.080756  204.27
# 47802  43369 -3.365319  2.426503 -3.752227  ... -1.055997 -1.200165 -1.012066   88.00
# 48094  43494 -1.278138  0.716242 -1.143279  ... -0.349793  0.454851  0.137843   24.90
# 50211  44393 -4.617461  3.663395 -5.297446  ... -0.239996 -0.183463 -0.073360    1.00
# 50537  44532 -0.234922  0.355413  1.972183  ... -0.531846  0.123185  0.039581    1.00
#
# [300 rows x 30 columns]

# %%
print(Y)
# Out:
# 25897    0.0
# 7103     0.0
# 30289    0.0
# 3106     0.0
# 2630     0.0
#         ...
# 46998    1.0
# 47802    1.0
# 48094    1.0
# 50211    1.0
# 50537    1.0
# Name: Class, Length: 300, dtype: float64

# %% [markdown]
# Split the data into Training data and Testing data

# %%
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.2,stratify=Y,random_state=2)

# %%
print(X.shape,X_train.shape,X_test.shape)
# Out:
# (300, 30) (240, 30) (60, 30)

# %% [markdown]
# Model Training

# %% [markdown]
# Logistic Regression

# %%
model = LogisticRegression()

# %%
# training the logistic regression model with training data
model.fit(X_train,Y_train)
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %% [markdown]
# Model Evaluation

# %% [markdown]
# Accuracy Score

# %%
# accuracy on training data
X_train_prediction = model.predict(X_train)
training_data_accuracy = accuracy_score(X_train_prediction,Y_train)

# %%
print('Accuracy on training data:',training_data_accuracy)
# Out:
# Accuracy on training data: 0.9791666666666666

# %%
# accuracy on test data
X_test_prediction = model.predict(X_test)
test_data_accuracy = accuracy_score(X_test_prediction,Y_test)

# %%
print('Accuracy on test data:',test_data_accuracy)
# Out:
# Accuracy on test data: 0.95
